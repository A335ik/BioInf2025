# %% [markdown]
# # Домашнее задание №4

# %% [markdown]
# Я исследовал тяжёлую цепь ферритина различных живых организмов: человек (Homo sapiens), свинья (Sus scrofa), крыса (Rattus norvegicus) и дрозофила (Drosophila melanogaster)

# %% [markdown]
# При помощи инструмента MAFFT я получил следующий файл newick:

# %% [markdown]
# ((
# 1_sp_P19132_FRIH_RAT_Ferritin_heavy_chain_OS=Rattus_norvegicus_OX=10116_GN=Fth1_PE=1_SV=3
# :0.0013,
# 2_sp_Q7KRU8_FRIH_DROME_Ferritin_heavy_chain_OS=Drosophila_melanogaster_OX=7227_GN=Fer1HCH_PE=1_SV=1
# :1.4186):0.0269,
# 4_sp_P02794_FRIH_HUMAN_Ferritin_heavy_chain_OS=Homo_sapiens_OX=9606_GN=FTH1_PE=1_SV=2
# :0.0000,
# 3_sp_P19130_FRIH_PIG_Ferritin_heavy_chain_OS=Sus_scrofa_OX=9823_GN=FTH1_PE=1_SV=3
# :0.1481);

# %% [markdown]
#  С помощью  инструмента tree viewer сайта ETE Toolkit построил филогенетическое дерево:

# %% [markdown]
# ![tree.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# В этом дереве крыса и дрозофила находятся в одной монофилетической группе, а человек и свинья далеки от них.
