# %% [markdown]
# Начнём с создания ссылок в своей папке на файлы задания:

# %% [markdown]
# ![Снимок экрана (74).png](data:image/png;base64,...)

# %% [markdown]
# Используем fastqc и multiqc. По данным fastqc видно, что нужен тримминг:

# %% [markdown]
# ![before1.png](data:image/png;base64,...)

# %% [markdown]
# ![before2.png](data:image/png;base64,...)

# %% [markdown]
# Проведём тримминг с помощью fastp, новые результаты:

# %% [markdown]
# ![Снимок экрана (77).png](data:image/png;base64,...)

# %% [markdown]
# ![Снимок экрана (78).png](data:image/png;base64,...)

# %% [markdown]
# Стало лучше, особенно последние нуклеотиды. Далее будем использовать данные после тримминга - лучше точность и достоверность выравнивания. Использовать STAR не получилось...
