# %% [markdown]
# Сначала скопируем себе в папку необходимые прочтения и адаптеры. Запустим fastqc и multiqc на файлах illumina_reads_R1_001.fastq и illumina_reads_R2_001.fastq, получим следующие результаты:

# %% [markdown]
# ![Снимок экрана (84).png](data:image/png;base64,...)

# %% [markdown]
# ![Снимок экрана (83).png](data:image/png;base64,...)

# %% [markdown]
# R2 совсем плохо, R1 тоже не очень. Проведём тримминг, используя trimmomatics (скрипт прилагается).

# %% [markdown]
# ![Снимок экрана (81).png](data:image/png;base64,...)

# %% [markdown]
# ![Снимок экрана (82).png](data:image/png;base64,...)

# %% [markdown]
# Стало ощутимо лучше, пропали красные кресты, в том числе связанные с содержанием адаптеров. Качество файлов удовлетворительное, но я решил прогнать скрипт ещё раз, заменив SLIDINGWINDOW:4:15: на SLIDINGWINDOW:4:20:

# %% [markdown]
# ![Снимок экрана (86).png](data:image/png;base64,...)

# %% [markdown]
# ![Снимок экрана (85).png](data:image/png;base64,...)

# %% [markdown]
# Теперь все выглядит хорошо. Все multiqc репорты, а также скрипт приложены на гитхабе.
