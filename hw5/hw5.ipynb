# %% [markdown]
# Задание 1. Поиск последовательностей по фрагменту с использованием алгоритма blastp в базе данных nr даёт следующие результаты:

# %% [markdown]
# ![Снимок экрана (57).png](data:image/png;base64,...)

# %% [markdown]
# Видно, что участок белка принадлежит родопсину Bos Taurus.

# %% [markdown]
# С фильтром Homo Sapiens в базе nr результатов нет, поэтому переходим в базу данных UniProt (swissprot). Используем алгоритм blastp, так как ищем именно белок, могут быть замены нуклеотидов, не меняющие аминокислоту - они нас не интересуют.

# %% [markdown]
# ![Снимок экрана (58).png](data:image/png;base64,...)

# %% [markdown]
# Найден человеческий родопсин, похожий на бычий (86,7%). В описании этого белка найдём раздел keywords, содержащий информацию о связанном с дефектами белка заболевании - пигментном ретините.

# %% [markdown]
# ![Снимок экрана (60).png](data:image/png;base64,...)

# %% [markdown]
# Задание 2. Повторим действия семинара, но с транскриптомом другого вида. Сначала применим TransDecoder.LongOrfs (я взял вид Photinus pyralis)

# %% [markdown]
# ![Снимок экрана (61).png](data:image/png;base64,...)

# %% [markdown]
# Теперь укажем что база данных белковая, используем алгоритм BLAST, возьмём лучшие попадания и сформируем файл FASTA:

# %% [markdown]
# ![Снимок экрана (62).png](data:image/png;base64,...)
