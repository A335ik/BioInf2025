# %% [markdown]
# Я решил рассмотреть геномы коровы и лошади. Найдя их в базе данных и скачав с помощью datasets download genome accession <id генома вашего любимого организма> --include protein, я решил использовать мотив ДНК полимеразы А. Скачав его с сайта из задания, я использовал команду hmmsearch для проведения поиска по белкам:

# %% [markdown]
# ![Снимок экрана (69).png](data:image/png;base64,...)

# %% [markdown]
# ![Снимок экрана (70).png](data:image/png;base64,...)

# %% [markdown]
# После этого с использованием команды grep получил последовательности 2 верхних белков для каждого вида (с наименьшими e-value). Используя MEGA, провёл множественное выравнивание. Схожие участки видны, но домен оказался не очень консервативным:

# %% [markdown]
# ![Снимок экрана (71).png](data:image/png;base64,...)
