# %% [markdown]
# 1. Найдём 3 последовательности spike белка

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Создадим fasta файл и выровняем три найденные последовательности с одной из разобранных на семинаре

# %% [markdown]
# ![Снимок экрана (65).png](data:image/png;base64,...)

# %% [markdown]
# Построим дерево:

# %% [markdown]
# ![Снимок экрана (67).png](data:image/png;base64,...)

# %% [markdown]
# Две найденных последовательности близки друг к другу и к последовательности с семинара, а третья далека от остальных.

# %% [markdown]
# 2. Рассмотрим ортологи тяжелой цепи ферритина:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Построим дерево и для них. По этому дереву Danio rerio отстоит дальше всего от остальных, а человек ближе всего к лошади (Equus caballus)

# %% [markdown]
# ![Снимок экрана (68).png](data:image/png;base64,...)
